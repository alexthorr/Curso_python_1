# %%
import pandas as pd

# %%
fruit= "apple"
print(fruit)
# Out:
# apple

# %%
fruits =['piña', 'manzana', 'coco', 'pera']
print(fruit)
# Out:
# ['piña', 'manzana', 'sandia', 'pera', 'platano']

# %%
print(fruits[2])
# Out:
# coco

# %%
fruits[2]= "sandia"

# %%
print(fruits)
# Out:
# ['piña', 'manzana', 'sandia', 'pera']

# %%
fruits.append('platano')

# %%
print(fruits)
# Out:
# ['piña', 'manzana', 'sandia', 'pera', 'platano']

# %%
for fruit in fruits: 
    print(fruit)
# Out:
# piña
# manzana
# sandia
# pera
# platano

# %%
fruits.remove("sandia")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fruits.remove("sandia")
#
# ValueError: list.remove(x): x not in list

# %%
print(fruits)
# Out:
# ['piña', 'manzana', 'pera', 'platano']

# %%
print(dir(fruits))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
fruits.sort()
print(fruits)
# Out:
# ['manzana', 'pera', 'piña', 'platano']

# %%
#fruits.reverse()
#print(fruits)
#fruits.index("manzana")

# %%
fruits= {"apple", "orange", "banana", "coco", "watermelon"}
#print(dir(fruits))
#print(help(fruits))
print(len(fruits))
# Out:
# 5
